# %%
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.pornhub.com/video?o=mv&t=a&cc=world&page={n}"
url = 'https://www.pornhub.com/view_video.php?viewkey=6663545841fc0'
# page = urlopen(url.format(n=1))
page = urlopen(url)
html = page.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="RTA-5042-1996-1400-1577-RTA" name="rating">
# <meta content="adult" name="rating"/>
# <link href="https://apt-cucaaxacf9ghehaw.z01.azurefd.net/_content/Av.Client.UiComponents/ph/favicon.ico" rel="icon favicon" sizes="any"/>
# <link href="https://apt-cucaaxacf9ghehaw.z01.azurefd.net/_content/Av.Client.UiComponents/ph/favicon.png" rel="icon" type="image/png"/>
# <link href="https://apt-cucaaxacf9ghehaw.z01.azurefd.net/_content/Av.Client.UiComponents/ph/favicon.svg" rel="icon" type="image/svg+xml"/>
# <title>Pornhub</title>
# <link href="https://apt-cucaaxacf9ghehaw.z01.azurefd.net/dist/age-wall.min.b365bc00d37dd1929f74421ad6171625.css" rel="stylesheet"/>
# <script>
#     (function (w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' });
# ...
